# %%
# !pwd

# %%
# !ls
# Out:
# README.md    deep_core.ipynb  main     requirements.txt
# __pycache__  deepcore	      main.py  utils.py

# %%
# %pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 12.2 MB 6.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 499 kB 34.7 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !CUDA_VISIBLE_DEVICES=0 python -u main.py \
    --fraction 0.1 --dataset CIFAR10 \
    --data_path /home/studio-lab-user/all_data/datasets --num_exp 1 \
    --workers 2 --epochs 10 --optimizer SGD -se 10 --selection Uniform --model ResNet18 \
    --lr 0.1  \
    -sp /home/studio-lab-user/all_data/result --batch 128
# Out:
# ================== Exp 0 ==================
#
# dataset: CIFAR10, model: ResNet18, selection: Uniform, num_ex: 1, epochs: 10, fraction: 0.1, seed: 32398, lr: 0.1, save_path: /home/studio-lab-user/all_data/result, resume: , device: cuda, checkpoint_name: CIFAR10_ResNet18_Uniform_exp0_epoch10_2023-02-15 19:07:12.937863_0.1_
#
# Files already downloaded and verified
# Files already downloaded and verified
# Number of points chosen: 5000
# => Saving checkpoint for epoch 0, with Prec@1 0.000000.
# Epoch: [0][0/40]	Time 0.236 (0.236)	Loss 2.3230 (2.3230)	Prec@1 10.156 (10.156)
# Epoch: [0][20/40]	Time 0.147 (0.156)	Loss 3.6110 (4.4593)	Prec@1 18.750 (11.533)
# Test: [0/79]	Time 0.119 (0.119)	Loss 18.5816 (18.5816)	Prec@1 10.156 (10.156)
# Test: [20/79]	Time 0.028 (0.032)	Loss 9.6943 (14.4748)	Prec@1 20.312 (13.914)
# Test: [40/79]	Time 0.028 (0.030)	Loss 15.5984 (14.2850)	Prec@1 21.094 (14.729)
# Test: [60/79]	Time 0.028 (0.030)	Loss 20.3280 (14.1680)	Prec@1 17.188 (15.087)
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python -u main.py \
    --fraction 0.1 --dataset CIFAR10 \
    --data_path /home/studio-lab-user/all_data/datasets --num_exp 1 \
    --workers 2 --epochs 1 --optimizer SGD -se 10 --selection GrandSecond --model ResNet18 \
    --lr 0.1  --selection_epochs 1\
    -sp /home/studio-lab-user/all_data/result --batch 128
# Out:
# ================== Exp 0 ==================
#
# dataset: CIFAR10, model: ResNet18, selection: GrandSecond, num_ex: 1, epochs: 1, fraction: 0.1, seed: 43546, lr: 0.1, save_path: /home/studio-lab-user/all_data/result, resume: , device: cpu, checkpoint_name: CIFAR10_ResNet18_GrandSecond_exp0_epoch1_2023-02-10 00:00:43.548238_0.1_
#
# Files already downloaded and verified
# Files already downloaded and verified
# Using CPU.
#
# => Training Epoch #0
# | Epoch [  0/  1] Iter[  1/50001]		Loss: 2.5192
# | Epoch [  0/  1] Iter[ 21/50001]		Loss: 2.2664
# | Epoch [  0/  1] Iter[ 41/50001]		Loss: 2.2542
# | Epoch [  0/  1] Iter[ 61/50001]		Loss: 2.2460
# | Epoch [  0/  1] Iter[ 81/50001]		Loss: 2.5615
# | Epoch [  0/  1] Iter[101/50001]		Loss: 2.6196
# | Epoch [  0/  1] Iter[121/50001]		Loss: 1.8832
# | Epoch [  0/  1] Iter[141/50001]		Loss: 2.2893
# | Epoch [  0/  1] Iter[161/50001]		Loss: 1.9328
# | Epoch [  0/  1] Iter[181/50001]		Loss: 2.4178
# ...

# %% [markdown]
# ### EL2N_Kmeans

# %%
#test run

# %%
# !CUDA_VISIBLE_DEVICES=0 python -u main.py \
    --fraction 0.1 --dataset CIFAR10 \
    --data_path /home/studio-lab-user/all_data/datasets --num_exp 1 \
    --workers 2 --epochs 5 --optimizer SGD -se 10 --selection EL2NkMeans --model ResNet18 \
    --lr 0.1 --selection_epochs 2 \
    --kmeans_d_intermediate 24 --kmeans_el2n_scoring_method 'weighted' --el2n_epochs 0 --el2n_repeat 2 \
    -sp /home/studio-lab-user/all_data/result --batch 128
# Out:
# ================== Exp 0 ==================
#
# dataset: CIFAR10, model: ResNet18, selection: EL2NkMeans, num_ex: 1, epochs: 5, fraction: 0.1, seed: 25738, lr: 0.1, save_path: /home/studio-lab-user/all_data/result, resume: , device: cpu, checkpoint_name: CIFAR10_ResNet18_EL2NkMeans_exp0_epoch5_2023-02-07 21:50:25.745964_0.1_
#
# Files already downloaded and verified
# Files already downloaded and verified
# Using CPU.
# ^C
# Traceback (most recent call last):
#   File "/home/studio-lab-user/deepcore_coresets/main.py", line 345, in <module>
#     main()
#   File "/home/studio-lab-user/deepcore_coresets/main.py", line 179, in main
#     subset = method.select()
#   File "/home/studio-lab-user/deepcore_coresets/deepcore/methods/el2n_kmeans.py", line 246, in select
#     all_el2n_scores = self._get_el2n_scores()
#   File "/home/studio-lab-user/deepcore_coresets/deepcore/methods/el2n_kmeans.py", line 232, in _get_el2n_scores
#     self.run()
# ...

# %%
#prod run

# %%
# !CUDA_VISIBLE_DEVICES=0 python -u main.py \
    --fraction 0.1 --dataset CIFAR10 \
    --data_path /home/studio-lab-user/all_data/datasets --num_exp 1 \
    --workers 2 --epochs 200 --optimizer SGD -se 10 --selection EL2NkMeans --model ResNet18 \
    --lr 0.1 --selection_epochs 20 \
    --kmeans_d_intermediate 24 --kmeans_el2n_scoring_method 'weighted' --el2n_epochs 0 --el2n_repeat 10 \
    -sp /home/studio-lab-user/all_data/result --batch 128
# Out:
# ================== Exp 0 ==================
#
# dataset: CIFAR10, model: ResNet18, selection: EL2NkMeans, num_ex: 1, epochs: 200, fraction: 0.1, seed: 72907, lr: 0.1, save_path: /home/studio-lab-user/all_data/result, resume: , device: cuda, checkpoint_name: CIFAR10_ResNet18_EL2NkMeans_exp0_epoch200_2023-02-01 22:24:33.474216_0.1_
#
# Files already downloaded and verified
# Files already downloaded and verified
# Run 0 times for EL2N score calculation
# Run 1 times for EL2N score calculation
# Run 2 times for EL2N score calculation
# Run 3 times for EL2N score calculation
# Run 4 times for EL2N score calculation
# Run 5 times for EL2N score calculation
# Run 6 times for EL2N score calculation
# Run 7 times for EL2N score calculation
# Run 8 times for EL2N score calculation
# Run 9 times for EL2N score calculation
# El2N score calculations done
#
# => Training Epoch #0
# | Epoch [  0/ 20] Iter[  1/391]		Loss: 2.5310
# | Epoch [  0/ 20] Iter[ 21/391]		Loss: 5.0052
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python -u main.py \
    --fraction 0.1 --dataset CIFAR10 \
    --data_path /home/studio-lab-user/all_data/datasets --num_exp 1 \
    --workers 2 --epochs 200 --optimizer SGD -se 10 --selection EL2NkMeans --model ResNet18 \
    --lr 0.1 --selection_epochs 20 \
    --kmeans_d_intermediate 24 --kmeans_el2n_scoring_method 'max_score' --el2n_epochs 0 --el2n_repeat 10 \
    -sp /home/studio-lab-user/all_data/result --batch 128
# Out:
# ================== Exp 0 ==================
#
# dataset: CIFAR10, model: ResNet18, selection: EL2NkMeans, num_ex: 1, epochs: 200, fraction: 0.1, seed: 83801, lr: 0.1, save_path: /home/studio-lab-user/all_data/result, resume: , device: cuda, checkpoint_name: CIFAR10_ResNet18_EL2NkMeans_exp0_epoch200_2023-02-03 23:24:44.348812_0.1_
#
# Files already downloaded and verified
# Files already downloaded and verified
# Run 0 times for EL2N score calculation
# Run 1 times for EL2N score calculation
# Run 2 times for EL2N score calculation
# Run 3 times for EL2N score calculation
# Run 4 times for EL2N score calculation
# Run 5 times for EL2N score calculation
# Run 6 times for EL2N score calculation
# Run 7 times for EL2N score calculation
# Run 8 times for EL2N score calculation
# Run 9 times for EL2N score calculation
# El2N score calculations done
#
# => Training Epoch #0
# | Epoch [  0/ 20] Iter[  1/391]		Loss: 2.5965
# | Epoch [  0/ 20] Iter[ 21/391]		Loss: 4.6233
# ...

# %% [markdown]
# ## Grand Score

# %%
# !CUDA_VISIBLE_DEVICES=0 python -u main.py \
    --fraction 0.1 --dataset CIFAR10 \
    --data_path /home/studio-lab-user/all_data/datasets --num_exp 1 \
    --workers 2 --epochs 200 --optimizer SGD -se 10 --selection GrandSecond --model ResNet18 \
    --lr 0.1  --selection_epochs 1\
    -sp /home/studio-lab-user/all_data/result --batch 128
# Out:
# ================== Exp 0 ==================
#
# dataset: CIFAR10, model: ResNet18, selection: GrandSecond, num_ex: 1, epochs: 200, fraction: 0.1, seed: 35693, lr: 0.1, save_path: /home/studio-lab-user/all_data/result, resume: , device: cuda, checkpoint_name: CIFAR10_ResNet18_GrandSecond_exp0_epoch200_2023-02-10 01:40:36.237155_0.1_
#
# Files already downloaded and verified
# Files already downloaded and verified
#
# => Training Epoch #0
# | Epoch [  0/  1] Iter[  1/50001]		Loss: 2.8288
# | Epoch [  0/  1] Iter[5001/50001]		Loss: 1.7069
# | Epoch [  0/  1] Iter[10001/50001]		Loss: 1.8950
# | Epoch [  0/  1] Iter[15001/50001]		Loss: 2.7470
# | Epoch [  0/  1] Iter[20001/50001]		Loss: 1.8602
# | Epoch [  0/  1] Iter[25001/50001]		Loss: 2.1709
# | Epoch [  0/  1] Iter[30001/50001]		Loss: 1.8599
# | Epoch [  0/  1] Iter[35001/50001]		Loss: 3.2693
# | Epoch [  0/  1] Iter[40001/50001]		Loss: 1.6383
# | Epoch [  0/  1] Iter[45001/50001]		Loss: 2.7314
# ...

# %% [markdown]
# ## EL2N scores

# %%
# !CUDA_VISIBLE_DEVICES=0 python -u main.py \
    --fraction 0.1 --dataset CIFAR10 \
    --data_path /home/studio-lab-user/all_data/datasets --num_exp 1 \
    --workers 2 --epochs 200 --optimizer SGD -se 10 --selection EL2N --model ResNet18 \
    --lr 0.1 --selection_epochs 2 \
    --kmeans_d_intermediate 24 --kmeans_el2n_scoring_method 'max_score' --el2n_repeat 10 \
    -sp /home/studio-lab-user/all_data/result --batch 128
# Out:
# ================== Exp 0 ==================
#
# dataset: CIFAR10, model: ResNet18, selection: EL2N, num_ex: 1, epochs: 200, fraction: 0.1, seed: 73276, lr: 0.1, save_path: /home/studio-lab-user/all_data/result, resume: , device: cuda, checkpoint_name: CIFAR10_ResNet18_EL2N_exp0_epoch200_2023-02-15 19:17:53.817407_0.1_
#
# Files already downloaded and verified
# Files already downloaded and verified
#
# => Training Epoch #0
# | Epoch [  0/  2] Iter[  1/391]		Loss: 2.4464
# | Epoch [  0/  2] Iter[ 21/391]		Loss: 2.3201
# | Epoch [  0/  2] Iter[ 41/391]		Loss: 2.3280
# | Epoch [  0/  2] Iter[ 61/391]		Loss: 2.2763
# | Epoch [  0/  2] Iter[ 81/391]		Loss: 2.2433
# | Epoch [  0/  2] Iter[101/391]		Loss: 2.1950
# | Epoch [  0/  2] Iter[121/391]		Loss: 2.1300
# | Epoch [  0/  2] Iter[141/391]		Loss: 2.0792
# | Epoch [  0/  2] Iter[161/391]		Loss: 1.8786
# | Epoch [  0/  2] Iter[181/391]		Loss: 1.9254
# | Epoch [  0/  2] Iter[201/391]		Loss: 1.8199
# ...

# %% [markdown]
# ## Grand Score-Kmeans

# %%
# test

# %%
# !CUDA_VISIBLE_DEVICES=0 python -u main.py \
    --fraction 0.1 --dataset CIFAR10 \
    --data_path /home/studio-lab-user/all_data/datasets --num_exp 1 \
    --workers 2 --epochs 10 --optimizer SGD -se 10 --selection ScoredkMeans --model ResNet18 \
    --lr 0.1 --selection_epochs 5 \
    --kmeans_d_intermediate 24 --kmeans_el2n_scoring_method 'max_score' --el2n_repeat 2 \
    --eg_selection_method 'el2n' --el2n_epochs=1\
    -sp /home/studio-lab-user/all_data/result --batch 128
# Out:
# ================== Exp 0 ==================
#
# dataset: CIFAR10, model: ResNet18, selection: ScoredkMeans, num_ex: 1, epochs: 10, fraction: 0.1, seed: 2926, lr: 0.1, save_path: /home/studio-lab-user/all_data/result, resume: , device: cuda, checkpoint_name: CIFAR10_ResNet18_ScoredkMeans_exp0_epoch10_2023-02-16 21:08:23.491017_0.1_
#
# Files already downloaded and verified
# Files already downloaded and verified
#
#             Scored Kmeans running with the following criterion:
#             eg. selection: el2n,
#             repeats: 2,
#             balance: True,
#             d_intermediate: 24,
#             kmeans_epochs: 5
#
# ^C
# Traceback (most recent call last):
#   File "/home/studio-lab-user/deepcore_coresets/main.py", line 387, in <module>
#     main()
#   File "/home/studio-lab-user/deepcore_coresets/main.py", line 208, in main
#     subset = method.select()
#   File "/home/studio-lab-user/deepcore_coresets/deepcore/methods/scoredkmeans.py", line 339, in select
# ...

# %%
#prod

# %%
# !CUDA_VISIBLE_DEVICES=0 python -u main.py \
    --fraction 0.1 --dataset CIFAR10 \
    --data_path /home/studio-lab-user/all_data/datasets --num_exp 1 \
    --workers 2 --epochs 200 --optimizer SGD -se 10 --selection ScoredkMeans --model ResNet18 \
    --lr 0.1 --selection_epochs 20 \
    --kmeans_d_intermediate 24 --kmeans_el2n_scoring_method 'max_score' --el2n_repeat 10 \
    --eg_selection_method 'grand' --el2n_epochs=1 \
    -sp /home/studio-lab-user/all_data/result --batch 128
# Out:
# ================== Exp 0 ==================
#
# dataset: CIFAR10, model: ResNet18, selection: ScoredkMeans, num_ex: 1, epochs: 200, fraction: 0.1, seed: 21173, lr: 0.1, save_path: /home/studio-lab-user/all_data/result, resume: , device: cuda, checkpoint_name: CIFAR10_ResNet18_ScoredkMeans_exp0_epoch200_2023-02-16 21:08:41.737839_0.1_
#
# Files already downloaded and verified
# Files already downloaded and verified
#
#             Scored Kmeans running with the following criterion:
#             eg. selection: grand,
#             repeats: 10,
#             balance: True,
#             d_intermediate: 24,
#             kmeans_epochs: 20
#
#
# => Training Epoch #0
# | Epoch [  0/  1] Iter[  1/50001]		Loss: 2.2272
# | Epoch [  0/  1] Iter[2561/50001]		Loss: 1.8801
# | Epoch [  0/  1] Iter[5121/50001]		Loss: 2.2086
# | Epoch [  0/  1] Iter[7681/50001]		Loss: 2.5595
# | Epoch [  0/  1] Iter[10241/50001]		Loss: 2.4705
# | Epoch [  0/  1] Iter[12801/50001]		Loss: 2.4828
# ...

# %% [markdown]
# ## EL2N-Kmeans Again

# %%
# !CUDA_VISIBLE_DEVICES=0 python -u main.py \
    --fraction 0.1 --dataset CIFAR10 \
    --data_path /home/studio-lab-user/all_data/datasets --num_exp 1 \
    --workers 2 --epochs 200 --optimizer SGD -se 10 --selection EL2NkMeans --model ResNet18 \
    --lr 0.1 --selection_epochs 20 \
    --kmeans_d_intermediate 24 --kmeans_el2n_scoring_method 'max_score' --el2n_epochs 0 --el2n_repeat 10 \
    -sp /home/studio-lab-user/all_data/result --batch 128
# Out:
# ================== Exp 0 ==================
#
# dataset: CIFAR10, model: ResNet18, selection: EL2NkMeans, num_ex: 1, epochs: 200, fraction: 0.1, seed: 15043, lr: 0.1, save_path: /home/studio-lab-user/all_data/result, resume: , device: cuda, checkpoint_name: CIFAR10_ResNet18_EL2NkMeans_exp0_epoch200_2023-02-17 21:30:15.627259_0.1_
#
# Files already downloaded and verified
# Files already downloaded and verified
# Run 0 times for EL2N score calculation
# Run 1 times for EL2N score calculation
# Run 2 times for EL2N score calculation
# Run 3 times for EL2N score calculation
# Run 4 times for EL2N score calculation
# Run 5 times for EL2N score calculation
# Run 6 times for EL2N score calculation
# Run 7 times for EL2N score calculation
# Run 8 times for EL2N score calculation
# Run 9 times for EL2N score calculation
# El2N score calculations done
#
# => Training Epoch #0
# | Epoch [  0/ 20] Iter[  1/391]		Loss: 2.4646
# | Epoch [  0/ 20] Iter[ 21/391]		Loss: 5.1088
# ...
